# %% [markdown]
# # Settings

# %%
# %env TF_KERAS = 1
import os
sep_local = os.path.sep

import sys
sys.path.append('..'+sep_local+'..')
print(sep_local)
# Out:
# env: TF_KERAS=1
# \

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.1.0

# %% [markdown]
# # Dataset loading

# %%
dataset_name='pokemon'

# %%
IMG_DIR = 'C:\\Users\\Khalid\\Documents\projects\\pokemon\DS06\\'
VAL_PCT = 10
VAL_FORMAT = 'png'

# %%
os.chdir('..'+sep_local+'..'+sep_local+'..'+sep_local+'..'+sep_local+'..')
print(os.getcwd())
# Out:
# C:\Users\Khalid\Documents\projects\Generatives\Generative_Models

# %%
from training.generators.file_image_generator import create_image_lists, get_generators
# Out:
# Using TensorFlow backend.

# %%
imgs_list = create_image_lists(
    image_dir=IMG_DIR, 
    validation_pct=VAL_PCT, 
    valid_imgae_formats=VAL_FORMAT
)
# Out:
#   DEBUG    | Looking for images in 'all'
#   INFO     | 809 file found

# %%
inputs_shape= IMG_SIZE=(200, 200, 3)
BATCH_SIZE = 32
latent_dim = 32
intermediate_dim = 32

# %%
train_gen, test_gen = get_generators(
    images_list=imgs_list, 
    image_dir=IMG_DIR, 
    image_size=IMG_SIZE, 
    batch_size=BATCH_SIZE, 
    class_mode=None
)
# Out:
#   INFO     | Found 738 training files
#   INFO     | Found 71 validation files

# %%
import tensorflow as tf

# %%
train_ds = tf.data.Dataset.from_generator(
    lambda: train_gen, 
    output_types=tf.float32 ,
    output_shapes=tf.TensorShape((BATCH_SIZE, ) + IMG_SIZE)
)

test_ds = tf.data.Dataset.from_generator(
    lambda: test_gen, 
    output_types=tf.float32 ,
    output_shapes=tf.TensorShape((BATCH_SIZE, ) + IMG_SIZE)
)

# %%
_instance_scale=1.0
for data in train_ds:
    _instance_scale = float(data[0].numpy().max())
    break

# %%
_instance_scale
# Out:
# 1.0

# %%
import numpy as np
from collections.abc import Iterable

# %%
if isinstance(inputs_shape, Iterable):
    _outputs_shape = np.prod(inputs_shape)

# %%
_outputs_shape
# Out:
# 120000

# %% [markdown]
# # Model's Layers definition

# %%
menc_lays = [tf.keras.layers.Dense(units=intermediate_dim//2, activation='relu'),
            tf.keras.layers.Dense(units=intermediate_dim//2, activation='relu'),
            tf.keras.layers.Flatten(),
            tf.keras.layers.Dense(units=latent_dim)]

venc_lays = [tf.keras.layers.Dense(units=intermediate_dim//2, activation='relu'),
            tf.keras.layers.Dense(units=intermediate_dim//2, activation='relu'),
            tf.keras.layers.Flatten(),
            tf.keras.layers.Dense(units=latent_dim)]

dec_lays = [tf.keras.layers.Dense(units=latent_dim, activation='relu'),
            tf.keras.layers.Dense(units=intermediate_dim, activation='relu'),
            tf.keras.layers.Dense(units=_outputs_shape),
            tf.keras.layers.Reshape(inputs_shape)]

# %% [markdown]
# # Model definition

# %%
model_name = dataset_name+'VAEssmi'
recoding_dir='..'+sep_local+'..'+sep_local+'recoding'+sep_local+model_name

# %%
from training.autoencoding_basic.autoencoders.VAE import VAE as AE

# %%
inputs_shape=IMG_SIZE

# %%
variables_params = \
[
    {
        'name': 'inference_mean', 
        'inputs_shape':inputs_shape,
        'outputs_shape':latent_dim,
        'layers': menc_lays#enc_lays2#
    },
    
    {
        'name': 'inference_logvariance', 
        'inputs_shape':inputs_shape,
        'outputs_shape':latent_dim,
        'layers': venc_lays#enc_lays2#
    },
        {
        'name': 'generative', 
        'inputs_shape':latent_dim,
        'outputs_shape':inputs_shape,
        'layers':dec_lays#dec_lays2#
    }
]

# %%
from utils.data_and_files.file_utils import create_if_not_exist

# %%
_restore = os.path.join(recoding_dir, 'var_save_dir')

# %%
create_if_not_exist(_restore)
_restore
# Out:
# '..\\..\\recoding\\pokemonVAEssmi\\var_save_dir'

# %%
#to restore trained model, set filepath=_restore

# %%
ae = AE( 
    name=model_name,
    inputs_shape=inputs_shape,
    outputs_shape=inputs_shape,
    latent_dim=latent_dim,
    batch_size=BATCH_SIZE,
    variables_params=variables_params, 
    filepath=None
    )
# Out:
# Model: "inference_mean"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inference_mean_inputs (Input [(None, 200, 200, 3)]     0
# _________________________________________________________________
# dense (Dense)                (None, 200, 200, 16)      64
# _________________________________________________________________
# dense_1 (Dense)              (None, 200, 200, 16)      272
# _________________________________________________________________
# flatten (Flatten)            (None, 640000)            0
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                20480032
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32)                128
# _________________________________________________________________
# dropout (Dropout)            (None, 32)                0
# _________________________________________________________________
# activity_regularization (Act (None, 32)                0
# _________________________________________________________________
# inference_mean_outputs (Acti (None, 32)                0
# =================================================================
# Total params: 20,480,496
# Trainable params: 20,480,432
# Non-trainable params: 64
# _________________________________________________________________
#   WARNING  | None
# Model: "inference_logvariance"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inference_logvariance_inputs [(None, 200, 200, 3)]     0
# _________________________________________________________________
# dense_3 (Dense)              (None, 200, 200, 16)      64
# _________________________________________________________________
# dense_4 (Dense)              (None, 200, 200, 16)      272
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 640000)            0
# _________________________________________________________________
# dense_5 (Dense)              (None, 32)                20480032
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32)                128
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# activity_regularization_1 (A (None, 32)                0
# _________________________________________________________________
# inference_logvariance_output (None, 32)                0
# =================================================================
# Total params: 20,480,496
# Trainable params: 20,480,432
# Non-trainable params: 64
# _________________________________________________________________
#   WARNING  | None
# Model: "generative"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# generative_inputs (InputLaye [(None, 32)]              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dense_7 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dense_8 (Dense)              (None, 120000)            3960000
# _________________________________________________________________
# reshape (Reshape)            (None, 200, 200, 3)       0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 200, 200, 3)       12
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 200, 200, 3)       0
# _________________________________________________________________
# activity_regularization_2 (A (None, 200, 200, 3)       0
# _________________________________________________________________
# generative_outputs (Activati (None, 200, 200, 3)       0
# =================================================================
# Total params: 3,962,124
# Trainable params: 3,962,118
# Non-trainable params: 6
# _________________________________________________________________
#   WARNING  | None

# %%
#from evaluation.quantitive_metrics.psnr import psnr
from evaluation.quantitive_metrics.ssmi import ssmi
#from evaluation.quantitive_metrics.sharp_diff import sharp_diff

# %%
ae.compile(loss={'x_logits': ssmi})
# Out:
# WARNING:tensorflow:Output inference_logvariance missing from loss dictionary. We assume this was done on purpose. The fit and evaluate APIs will not be expecting any data to be passed to inference_logvariance.
# WARNING:tensorflow:Output inference_mean missing from loss dictionary. We assume this was done on purpose. The fit and evaluate APIs will not be expecting any data to be passed to inference_mean.
# Model: "pokemonVAEssmi"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# inference_logvariance_inputs (I [(None, 200, 200, 3) 0
# __________________________________________________________________________________________________
# inference_logvariance (Model)   (None, 32)           20480496    inference_logvariance_inputs[0][0
# __________________________________________________________________________________________________
# tf_op_layer_mul (TensorFlowOpLa [(None, 32)]         0           inference_logvariance[1][0]
# __________________________________________________________________________________________________
# inference_mean_inputs (InputLay [(None, 200, 200, 3) 0
# __________________________________________________________________________________________________
# tf_op_layer_Exp (TensorFlowOpLa [(None, 32)]         0           tf_op_layer_mul[0][0]
# __________________________________________________________________________________________________
# inference_mean (Model)          (None, 32)           20480496    inference_mean_inputs[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_mul_1 (TensorFlowOp [(32, 32)]           0           tf_op_layer_Exp[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Exp_1 (TensorFlowOp [(None, 32)]         0           inference_logvariance[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_z_latent (TensorFlo [(32, 32)]           0           tf_op_layer_mul_1[0][0]
#                                                                  inference_mean[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sqrt (TensorFlowOpL [(None, 32)]         0           tf_op_layer_Exp_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_truediv (TensorFlow [(32, 32)]           0           tf_op_layer_z_latent[0][0]
#                                                                  tf_op_layer_Sqrt[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_truediv_1 (TensorFl [(None, 32)]         0           inference_mean[1][0]
#                                                                  tf_op_layer_Sqrt[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_SquaredDifference ( [(32, 32)]           0           tf_op_layer_truediv[0][0]
#                                                                  tf_op_layer_truediv_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Log (TensorFlowOpLa [(None, 32)]         0           tf_op_layer_Sqrt[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_mul_2 (TensorFlowOp [(32, 32)]           0           tf_op_layer_SquaredDifference[0][
# __________________________________________________________________________________________________
# tf_op_layer_add (TensorFlowOpLa [(None, 32)]         0           tf_op_layer_Log[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_sub (TensorFlowOpLa [(32, 32)]           0           tf_op_layer_mul_2[0][0]
#                                                                  tf_op_layer_add[0][0]
# __________________________________________________________________________________________________
# generative (Model)              multiple             3962124     tf_op_layer_z_latent[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_log_pdf (TensorFlow [(32, 32)]           0           tf_op_layer_sub[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_x_logits (TensorFlo [(32, 200, 200, 3)]  0           generative[1][0]
# ==================================================================================================
# Total params: 44,923,116
# Trainable params: 44,922,982
# Non-trainable params: 134
# __________________________________________________________________________________________________
# None

# %% [markdown]
# # Callbacks

# %%
from training.callbacks.progress_bar import NotebookPrograssBar
from training.callbacks.sample_generation import SampleGeneration
from training.callbacks.save_model import ModelSaver

# %%
progbar = NotebookPrograssBar(leave_outer=False)

# %%
es = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', 
    min_delta=1e-12, 
    patience=5, 
    verbose=1, 
    restore_best_weights=True
)

# %%
ms = ModelSaver(filepath=_restore,save_freq=5)

# %%
csv_dir = os.path.join(recoding_dir, 'csv_dir')
create_if_not_exist(csv_dir)
csv_dir = os.path.join(csv_dir, ae.name+'.csv')
csv_log = tf.keras.callbacks.CSVLogger(csv_dir, append=True)
csv_dir
# Out:
# '..\\..\\recoding\\pokemonVAEssmi\\csv_dir\\pokemonVAEssmi.csv'

# %%
image_gen_dir = os.path.join(recoding_dir, 'image_gen_dir')
create_if_not_exist(image_gen_dir)

# %%
sg = SampleGeneration(latent_shape=latent_dim, filepath=image_gen_dir, gen_freq=5, save_img=True, gray_plot=False)

# %%
import numpy as np

# %% [markdown]
# # Model Training

# %%
ae.fit(
    x=train_ds,
    input_kw=None,
    steps_per_epoch=750,
    epochs=int(1e6), 
    verbose=0,
    callbacks=[progbar, es, ms, csv_log, sg],
    workers=-1,
    use_multiprocessing=True,
    validation_data=test_ds,
    validation_steps=250
)
# Out:
# HBox(children=(IntProgress(value=0, description='Training', max=1000000, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Epoch 0', max=750, style=ProgressStyle(description_width='ini…
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# <ipython-input-37-a54a68f66328> in <module>
#       9     use_multiprocessing=True,
#      10     validation_data=test_ds,
# ---> 11     validation_steps=250
#      12 )
#
# ~\Documents\projects\Generatives\Generative_Models\training\autoencoding_basic\autoencoders\autoencoder.py in fit(self, x, y, input_kw, input_scale, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     111                 use_multiprocessing=use_multiprocessing,
#     112                 shuffle=shuffle,
# --> 113                 initial_epoch=initial_epoch
#     114             )
#     115
#
# C:\ProgramData\Anaconda3\envs\tf02\lib\site-packages\tensorflow_core\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     817         max_queue_size=max_queue_size,
#     818         workers=workers,
# --> 819         use_multiprocessing=use_multiprocessing)
#     820
#     821   def evaluate(self,
#
# C:\ProgramData\Anaconda3\envs\tf02\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     395                       total_epochs=1)
#     396                   cbks.make_logs(model, epoch_logs, eval_result, ModeKeys.TEST,
# --> 397                                  prefix='val_')
#     398
#     399     return model.history
#
# C:\ProgramData\Anaconda3\envs\tf02\lib\contextlib.py in __exit__(self, type, value, traceback)
#     128                 value = type()
#     129             try:
# --> 130                 self.gen.throw(type, value, traceback)
#     131             except StopIteration as exc:
#     132                 # Suppress StopIteration *unless* it's the same exception that
#
# C:\ProgramData\Anaconda3\envs\tf02\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in on_epoch(self, epoch, mode)
#     769       if mode == ModeKeys.TRAIN:
#     770         # Epochs only apply to `fit`.
# --> 771         self.callbacks.on_epoch_end(epoch, epoch_logs)
#     772       self.progbar.on_epoch_end(epoch, epoch_logs)
#     773
#
# C:\ProgramData\Anaconda3\envs\tf02\lib\site-packages\tensorflow_core\python\keras\callbacks.py in on_epoch_end(self, epoch, logs)
#     300     logs = logs or {}
#     301     for callback in self.callbacks:
# --> 302       callback.on_epoch_end(epoch, logs)
#     303
#     304   def on_train_batch_begin(self, batch, logs=None):
#
# ~\Documents\projects\Generatives\Generative_Models\training\callbacks\sample_generation.py in on_epoch_end(self, epoch, logs)
#      29                                                    inputs_shape=self.model.inputs_shape,
#      30                                                    latent_shape=[50, self.model.latent_dim],
# ---> 31                                                    eps=self.random_latent)
#      32             plot_and_save_generated(generated=generated, epoch=epoch, path=self.filepath, gray=self.gray_plot,
#      33                                     save=self.save_img)
#
# ~\Documents\projects\Generatives\Generative_Models\graphs\basics\AE_graph.py in generate_sample(model, inputs_shape, latent_shape, eps)
#      47     if eps is None:
#      48         eps = tf.random.normal(shape=latent_shape)
# ---> 49     generated = decode_fn(model=model, latent=eps, inputs_shape=inputs_shape, apply_sigmoid=True)
#      50     return generated
#
# ~\Documents\projects\Generatives\Generative_Models\graphs\basics\AE_graph.py in decode_fn(model, latent, inputs_shape, apply_sigmoid)
#      38
#      39 def decode_fn(model, latent, inputs_shape, apply_sigmoid=False):
# ---> 40     x_logits = model('generative', [latent])
#      41     if apply_sigmoid:
#      42         probs = tf.sigmoid(x_logits)
#
# ~\Documents\projects\Generatives\Generative_Models\training\autoencoding_basic\autoencoders\autoencoder.py in get_variable(self, var_name, param)
#     128
#     129     def get_variable(self, var_name, param):
# --> 130         return self.get_variables()[var_name](*param)
#     131
#     132     def save(self,
#
# C:\ProgramData\Anaconda3\envs\tf02\lib\site-packages\tensorflow_core\python\keras\engine\base_layer.py in __call__(self, inputs, *args, **kwargs)
#     820           with base_layer_utils.autocast_context_manager(
#     821               self._compute_dtype):
# --> 822             outputs = self.call(cast_inputs, *args, **kwargs)
#     823           self._handle_activity_regularization(inputs, outputs)
#     824           self._set_mask_metadata(inputs, outputs, input_masks)
#
# C:\ProgramData\Anaconda3\envs\tf02\lib\site-packages\tensorflow_core\python\keras\engine\network.py in call(self, inputs, training, mask)
#     715     return self._run_internal_graph(
#     716         inputs, training=training, mask=mask,
# --> 717         convert_kwargs_to_constants=base_layer_utils.call_context().saving)
#     718
#     719   def compute_output_shape(self, input_shape):
#
# C:\ProgramData\Anaconda3\envs\tf02\lib\site-packages\tensorflow_core\python\keras\engine\network.py in _run_internal_graph(self, inputs, training, mask, convert_kwargs_to_constants)
#     889
#     890           # Compute outputs.
# --> 891           output_tensors = layer(computed_tensors, **kwargs)
#     892
#     893           # Update tensor_dict.
#
# C:\ProgramData\Anaconda3\envs\tf02\lib\site-packages\tensorflow_core\python\keras\engine\base_layer.py in __call__(self, inputs, *args, **kwargs)
#     820           with base_layer_utils.autocast_context_manager(
#     821               self._compute_dtype):
# --> 822             outputs = self.call(cast_inputs, *args, **kwargs)
#     823           self._handle_activity_regularization(inputs, outputs)
#     824           self._set_mask_metadata(inputs, outputs, input_masks)
#
# C:\ProgramData\Anaconda3\envs\tf02\lib\site-packages\tensorflow_core\python\keras\layers\core.py in call(self, inputs)
#    1140         outputs = sparse_ops.sparse_tensor_dense_matmul(inputs, self.kernel)
#    1141       else:
# -> 1142         outputs = gen_math_ops.mat_mul(inputs, self.kernel)
#    1143     if self.use_bias:
#    1144       outputs = nn.bias_add(outputs, self.bias)
#
# C:\ProgramData\Anaconda3\envs\tf02\lib\site-packages\tensorflow_core\python\ops\gen_math_ops.py in mat_mul(a, b, transpose_a, transpose_b, name)
#    5614         pass  # Add nodes to the TensorFlow graph.
#    5615     except _core._NotOkStatusException as e:
# -> 5616       _ops.raise_from_not_ok_status(e, name)
#    5617   # Add nodes to the TensorFlow graph.
#    5618   if transpose_a is None:
#
# C:\ProgramData\Anaconda3\envs\tf02\lib\site-packages\tensorflow_core\python\framework\ops.py in raise_from_not_ok_status(e, name)
#    6604   message = e.message + (" name: " + name if name is not None else "")
#    6605   # pylint: disable=protected-access
# -> 6606   six.raise_from(core._status_to_exception(e.code, message), None)
#    6607   # pylint: enable=protected-access
#    6608
#
# C:\ProgramData\Anaconda3\envs\tf02\lib\site-packages\six.py in raise_from(value, from_value)
#
# InternalError: Blas GEMM launch failed : a.shape=(50, 32), b.shape=(32, 32), m=50, n=32, k=32 [Op:MatMul]
